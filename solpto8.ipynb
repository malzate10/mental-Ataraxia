# %% [markdown]
# <a href="https://colab.research.google.com/github/malzate10/mental-Ataraxia/blob/main/solpto8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalación de las bibliotecas necesarias
# !pip install openai langchain pdfminer.six pypdf sentence_transformers langchain-community tiktoken faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.8/367.8 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 58.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 55.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 41.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 14.6 MB/s eta 0:00:00
# ...

# %%
# !pip install openai langchain pdfminer.six pypdf sentence_transformers langchain-community tiktoken faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.1/249.1 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 34.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 36.7 MB/s eta 0:00:00
# ...

# %%
import os
import warnings
warnings.filterwarnings('ignore')
import openai
from langchain.document_loaders import PyPDFLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import ConversationalRetrievalChain
from langchain.llms import OpenAI
from getpass import getpass

# %%
from IPython.display import clear_output

# %%
# !pip install openai
# !pip install langchain
# !pip install langchain-community langchain-core
clear_output()

# %%
from langchain.document_loaders import OnlinePDFLoader

# %%
pdf_file_path = "/content/08785bba-en.pdf"

# %%
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader(pdf_file_path)
documents = loader.load()

# %%
import os
os.environ["OPENAI_API_KEY"] = 'your valid OpenAI API key with GPT-4 enabled'

# %%
documents[10].page_content
# Out:
# '  \uf07c 9 \nOECD EMPLOYMENT OUTLOOK 2023 © OECD 2023  \n  4 Artificial intelligence, job quality and inclusiveness  128 \nIn Brief  129 \nIntroduction  130 \n4.1. Workers with AI skills earn significant wage premiums, but it is too soon to see AI’s effects \non labour productivity  131 \n4.2. Using AI is associated with higher job satisfaction and occupational safety, but there are \nsome risks  137 \n4.3. AI -led reorganisation or automation of managers’ tasks has downstream effects on their \nsubordinates  140 \n4.4. The impact of AI on inclusiveness and bias in the labour market  144 \n4.5. Concluding remarks  147 \nReferences  148 \nNotes  153 \n5 Skill needs and policies in the age of artificial intelligence  155 \nIn Brief  156 \nIntroduction  157 \n5.1. The development and adoption of AI will have an impact on skill needs  157 \n5.2. Changes in skill needs call for new training opportunities  163 \n5.3. Firms imp lementing AI say they provide training to their employees, but
# ...

# %%
from langchain.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings()

query_result = embeddings.embed_query(documents[0].page_content)

query_result
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# [-0.03073296882212162,
#  0.06468769907951355,
#  -0.05160568654537201,
#  -0.07566481083631516,
#  -0.01837994158267975,
#  0.009640979580581188,
#  0.06530256569385529,
#  0.019796106964349747,
#  0.046823423355817795,
#  0.015680082142353058,
#  0.08942926675081253,
# ...

# %%
embeddings=OpenAIEmbeddings()

# %%
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI
